# %% [markdown]
# This notebook includes the implemention of the baseline model 2.0 on default data (lettuce) and another, bigger data set to evaluate the influence of more data on the baseline model.
#
# 1) Baseline Model 2.0 on original_dataset (e.g. Kaggle Lettuce NPK data)
# 2) Baseline Model 2.0 on data (e.g. maize disease dataset)

# %%
# !pip install scikit-learn

# %%
# !pip install opencv-python

# %% [markdown]
# __Preparations__

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import to_categorical
import os
import cv2
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
# 1)
# Define the directory path containing the images
data_directory = "/Users/linn/Desktop/original_dataset"
batch_size = 32
image_size = (64, 64)
data = tf.keras.utils.image_dataset_from_directory(
    data_directory,
    batch_size=batch_size,
    image_size = image_size,
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset="training")

val_data = tf.keras.utils.image_dataset_from_directory(
    data_directory,
    batch_size=batch_size,
    image_size=image_size,
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset="validation"
)
# Out:
# Found 282 files belonging to 4 classes.
# Using 226 files for training.
# Found 282 files belonging to 4 classes.
# Using 56 files for validation.

# %%
# 1)
# Print the class names
class_names = data.class_names
print("Class names:", class_names)
# Out:
# Class names: ['deficiency_nitrogen', 'deficiency_phosphorus', 'deficiency_potassium', 'healthy']

# %%
# 1)
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Define the baseline model architecture
model = tf.keras.Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(4, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 31, 31, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 683716 (2.61 MB)
# Trainable params: 683716 (2.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 1)
# Train the model
history = model.fit(data, validation_data= val_data, epochs=40)
# Out:
# Epoch 1/40
# 8/8 [==============================] - 2s 80ms/step - loss: 61.3503 - accuracy: 0.2566 - val_loss: 2.0620 - val_accuracy: 0.3571
# Epoch 2/40
# 8/8 [==============================] - 1s 66ms/step - loss: 1.6517 - accuracy: 0.3496 - val_loss: 1.2331 - val_accuracy: 0.3929
# Epoch 3/40
# 8/8 [==============================] - 2s 68ms/step - loss: 1.1577 - accuracy: 0.4956 - val_loss: 1.1321 - val_accuracy: 0.5357
# Epoch 4/40
# 8/8 [==============================] - 2s 64ms/step - loss: 0.8609 - accuracy: 0.6637 - val_loss: 1.0026 - val_accuracy: 0.6071
# Epoch 5/40
# 8/8 [==============================] - 2s 77ms/step - loss: 0.7861 - accuracy: 0.7124 - val_loss: 1.1019 - val_accuracy: 0.5536
# Epoch 6/40
# 8/8 [==============================] - 2s 73ms/step - loss: 0.6210 - accuracy: 0.7743 - val_loss: 0.9759 - val_accuracy: 0.6250
# Epoch 7/40
# 8/8 [==============================] - 2s 74ms/step - loss: 0.3705 - accuracy: 0.8850 - val_loss: 1.3079 - val_accuracy: 0.5893
# Epoch 8/40
# 8/8 [==============================] - 1s 61ms/step - loss: 0.2993 - accuracy: 0.8805 - val_loss: 1.8810 - val_accuracy: 0.5357
# Epoch 9/40
# 8/8 [==============================] - 2s 72ms/step - loss: 0.4767 - accuracy: 0.8186 - val_loss: 1.1935 - val_accuracy: 0.5714
# Epoch 10/40
# 8/8 [==============================] - 1s 72ms/step - loss: 0.4088 - accuracy: 0.8540 - val_loss: 0.9953 - val_accuracy: 0.6071
# Epoch 11/40
# 8/8 [==============================] - 2s 73ms/step - loss: 0.2591 - accuracy: 0.9071 - val_loss: 1.3813 - val_accuracy: 0.5893
# Epoch 12/40
# 8/8 [==============================] - 2s 64ms/step - loss: 0.1500 - accuracy: 0.9602 - val_loss: 0.9727 - val_accuracy: 0.7321
# Epoch 13/40
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1272 - accuracy: 0.9513 - val_loss: 1.0709 - val_accuracy: 0.7143
# Epoch 14/40
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0601 - accuracy: 0.9867 - val_loss: 1.2802 - val_accuracy: 0.7143
# Epoch 15/40
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0373 - accuracy: 0.9912 - val_loss: 1.2911 - val_accuracy: 0.6964
# Epoch 16/40
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 1.3269 - val_accuracy: 0.7143
# Epoch 17/40
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 1.3270 - val_accuracy: 0.7321
# Epoch 18/40
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.5296 - val_accuracy: 0.7143
# Epoch 19/40
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.5641 - val_accuracy: 0.6964
# Epoch 20/40
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.4507 - val_accuracy: 0.7143
# Epoch 21/40
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.5641 - val_accuracy: 0.7143
# Epoch 22/40
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.6190 - val_accuracy: 0.7143
# Epoch 23/40
# 8/8 [==============================] - 2s 79ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.8612 - val_accuracy: 0.6786
# Epoch 24/40
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.7401 - val_accuracy: 0.6964
# Epoch 25/40
# 8/8 [==============================] - 2s 75ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.9499 - val_accuracy: 0.6964
# Epoch 26/40
# 8/8 [==============================] - 2s 67ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.9005 - val_accuracy: 0.6786
# Epoch 27/40
# 8/8 [==============================] - 2s 75ms/step - loss: 6.7218e-04 - accuracy: 1.0000 - val_loss: 1.9037 - val_accuracy: 0.6786
# Epoch 28/40
# 8/8 [==============================] - 2s 72ms/step - loss: 5.8385e-04 - accuracy: 1.0000 - val_loss: 2.0309 - val_accuracy: 0.6429
# Epoch 29/40
# 8/8 [==============================] - 1s 62ms/step - loss: 4.7956e-04 - accuracy: 1.0000 - val_loss: 2.0484 - val_accuracy: 0.6786
# Epoch 30/40
# 8/8 [==============================] - 1s 63ms/step - loss: 4.1786e-04 - accuracy: 1.0000 - val_loss: 1.9777 - val_accuracy: 0.6786
# Epoch 31/40
# 8/8 [==============================] - 1s 68ms/step - loss: 5.3457e-04 - accuracy: 1.0000 - val_loss: 2.0027 - val_accuracy: 0.6607
# Epoch 32/40
# 8/8 [==============================] - 2s 70ms/step - loss: 4.8100e-04 - accuracy: 1.0000 - val_loss: 1.9915 - val_accuracy: 0.6607
# Epoch 33/40
# 8/8 [==============================] - 1s 63ms/step - loss: 4.0935e-04 - accuracy: 1.0000 - val_loss: 1.9768 - val_accuracy: 0.6786
# Epoch 34/40
# 8/8 [==============================] - 1s 63ms/step - loss: 3.1847e-04 - accuracy: 1.0000 - val_loss: 2.0949 - val_accuracy: 0.6786
# Epoch 35/40
# 8/8 [==============================] - 1s 70ms/step - loss: 2.6032e-04 - accuracy: 1.0000 - val_loss: 2.1271 - val_accuracy: 0.6607
# Epoch 36/40
# 8/8 [==============================] - 2s 69ms/step - loss: 2.3148e-04 - accuracy: 1.0000 - val_loss: 2.0666 - val_accuracy: 0.6786
# Epoch 37/40
# 8/8 [==============================] - 2s 77ms/step - loss: 2.1116e-04 - accuracy: 1.0000 - val_loss: 2.1772 - val_accuracy: 0.6607
# Epoch 38/40
# 8/8 [==============================] - 2s 75ms/step - loss: 1.8118e-04 - accuracy: 1.0000 - val_loss: 2.2892 - val_accuracy: 0.6429
# Epoch 39/40
# 8/8 [==============================] - 1s 69ms/step - loss: 1.5696e-04 - accuracy: 1.0000 - val_loss: 2.1910 - val_accuracy: 0.6429
# Epoch 40/40
# 8/8 [==============================] - 2s 86ms/step - loss: 1.3929e-04 - accuracy: 1.0000 - val_loss: 2.2073 - val_accuracy: 0.6429

# %%
# 1)
# Evaluate the model on the validation data
val_loss, val_accuracy = model.evaluate(val_data)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 2.2073 - accuracy: 0.6429
# Validation Loss: 2.2073233127593994
# Validation Accuracy: 0.6428571343421936

# %%
# 1)
# plotting the loss and accuracy
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy normalization')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss normalization')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %% [markdown]
# __New Data__
#
# So far the normal baseline model was used. Now the same pipeline will be used for data from another dataset. The new dataset has more images.

# %%
# 2)
# Define the directory path containing the images
data_directory = "/Users/linn/Desktop/data"
batch_size = 32
image_size = (64, 64)
data = tf.keras.utils.image_dataset_from_directory(
    data_directory,
    batch_size=batch_size,
    image_size = image_size,
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset="training")

val_data = tf.keras.utils.image_dataset_from_directory(
    data_directory,
    batch_size=batch_size,
    image_size=image_size,
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset="validation"
)
# Out:
# Found 4188 files belonging to 4 classes.
# Using 3351 files for training.
# Found 4188 files belonging to 4 classes.
# Using 837 files for validation.

# %%
# 2)
# Print the class names
class_names = data.class_names
print("Class names:", class_names)
# Out:
# Class names: ['Blight', 'Common_Rust', 'Gray_Leaf_Spot', 'Healthy']

# %%
# 2)
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Define the baseline model architecture
model = tf.keras.Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(4, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 62, 62, 32)        896
#
#  max_pooling2d_6 (MaxPoolin  (None, 31, 31, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_8 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 4608)              0
#
#  dense_4 (Dense)             (None, 128)               589952
#
#  dense_5 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 683716 (2.61 MB)
# Trainable params: 683716 (2.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 2)
# Train the model
history = model.fit(data, validation_data= val_data, epochs=40)
# Out:
# Epoch 1/40
# 105/105 [==============================] - 7s 59ms/step - loss: 3.6705 - accuracy: 0.7165 - val_loss: 0.4421 - val_accuracy: 0.8148
# Epoch 2/40
# 105/105 [==============================] - 6s 57ms/step - loss: 0.4306 - accuracy: 0.8278 - val_loss: 0.5041 - val_accuracy: 0.8005
# Epoch 3/40
# 105/105 [==============================] - 6s 57ms/step - loss: 0.3130 - accuracy: 0.8678 - val_loss: 0.3481 - val_accuracy: 0.8471
# Epoch 4/40
# 105/105 [==============================] - 6s 55ms/step - loss: 0.2740 - accuracy: 0.8827 - val_loss: 0.2954 - val_accuracy: 0.8853
# Epoch 5/40
# 105/105 [==============================] - 6s 56ms/step - loss: 0.2203 - accuracy: 0.9102 - val_loss: 0.2937 - val_accuracy: 0.8746
# Epoch 6/40
# 105/105 [==============================] - 6s 57ms/step - loss: 0.2184 - accuracy: 0.9114 - val_loss: 0.3765 - val_accuracy: 0.8710
# Epoch 7/40
# 105/105 [==============================] - 6s 57ms/step - loss: 0.2069 - accuracy: 0.9132 - val_loss: 0.3507 - val_accuracy: 0.8722
# Epoch 8/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.1895 - accuracy: 0.9257 - val_loss: 0.3335 - val_accuracy: 0.8710
# Epoch 9/40
# 105/105 [==============================] - 7s 62ms/step - loss: 0.1469 - accuracy: 0.9451 - val_loss: 0.3568 - val_accuracy: 0.8590
# Epoch 10/40
# 105/105 [==============================] - 7s 65ms/step - loss: 0.1388 - accuracy: 0.9442 - val_loss: 0.3327 - val_accuracy: 0.8757
# Epoch 11/40
# 105/105 [==============================] - 7s 63ms/step - loss: 0.1570 - accuracy: 0.9427 - val_loss: 0.3700 - val_accuracy: 0.8746
# Epoch 12/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.1769 - accuracy: 0.9275 - val_loss: 0.4708 - val_accuracy: 0.8471
# Epoch 13/40
# 105/105 [==============================] - 7s 59ms/step - loss: 0.1069 - accuracy: 0.9630 - val_loss: 0.3729 - val_accuracy: 0.8829
# Epoch 14/40
# 105/105 [==============================] - 6s 58ms/step - loss: 0.0762 - accuracy: 0.9743 - val_loss: 0.3814 - val_accuracy: 0.8769
# Epoch 15/40
# 105/105 [==============================] - 6s 59ms/step - loss: 0.0618 - accuracy: 0.9785 - val_loss: 0.4171 - val_accuracy: 0.8662
# Epoch 16/40
# 105/105 [==============================] - 6s 59ms/step - loss: 0.0660 - accuracy: 0.9758 - val_loss: 0.4369 - val_accuracy: 0.8769
# Epoch 17/40
# 105/105 [==============================] - 6s 59ms/step - loss: 0.0613 - accuracy: 0.9794 - val_loss: 0.4012 - val_accuracy: 0.8841
# Epoch 18/40
# 105/105 [==============================] - 6s 59ms/step - loss: 0.2180 - accuracy: 0.9326 - val_loss: 0.5051 - val_accuracy: 0.8447
# Epoch 19/40
# 105/105 [==============================] - 6s 59ms/step - loss: 0.1443 - accuracy: 0.9475 - val_loss: 0.6320 - val_accuracy: 0.8363
# Epoch 20/40
# 105/105 [==============================] - 7s 59ms/step - loss: 0.0965 - accuracy: 0.9690 - val_loss: 0.4122 - val_accuracy: 0.8889
# Epoch 21/40
# 105/105 [==============================] - 7s 59ms/step - loss: 0.0434 - accuracy: 0.9872 - val_loss: 0.4865 - val_accuracy: 0.8925
# Epoch 22/40
# 105/105 [==============================] - 7s 59ms/step - loss: 0.0489 - accuracy: 0.9848 - val_loss: 0.5289 - val_accuracy: 0.8746
# Epoch 23/40
# 105/105 [==============================] - 7s 60ms/step - loss: 0.0322 - accuracy: 0.9899 - val_loss: 0.5406 - val_accuracy: 0.8769
# Epoch 24/40
# 105/105 [==============================] - 7s 60ms/step - loss: 0.0278 - accuracy: 0.9934 - val_loss: 0.5774 - val_accuracy: 0.8781
# Epoch 25/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0278 - accuracy: 0.9952 - val_loss: 0.5932 - val_accuracy: 0.8973
# Epoch 26/40
# 105/105 [==============================] - 7s 60ms/step - loss: 0.0173 - accuracy: 0.9958 - val_loss: 0.5377 - val_accuracy: 0.8853
# Epoch 27/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0246 - accuracy: 0.9928 - val_loss: 0.5491 - val_accuracy: 0.8757
# Epoch 28/40
# 105/105 [==============================] - 7s 60ms/step - loss: 0.1051 - accuracy: 0.9693 - val_loss: 0.6230 - val_accuracy: 0.8734
# Epoch 29/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0906 - accuracy: 0.9749 - val_loss: 0.5133 - val_accuracy: 0.8662
# Epoch 30/40
# 105/105 [==============================] - 7s 60ms/step - loss: 0.0645 - accuracy: 0.9821 - val_loss: 0.7164 - val_accuracy: 0.8471
# Epoch 31/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0817 - accuracy: 0.9749 - val_loss: 0.6219 - val_accuracy: 0.8650
# Epoch 32/40
# 105/105 [==============================] - 7s 60ms/step - loss: 0.0374 - accuracy: 0.9881 - val_loss: 0.6497 - val_accuracy: 0.8817
# Epoch 33/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.5987 - val_accuracy: 0.8841
# Epoch 34/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0088 - accuracy: 0.9967 - val_loss: 0.6520 - val_accuracy: 0.8805
# Epoch 35/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0861 - accuracy: 0.9767 - val_loss: 0.5606 - val_accuracy: 0.8698
# Epoch 36/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0494 - accuracy: 0.9842 - val_loss: 0.5931 - val_accuracy: 0.8722
# Epoch 37/40
# 105/105 [==============================] - 7s 62ms/step - loss: 0.0380 - accuracy: 0.9907 - val_loss: 0.6270 - val_accuracy: 0.8781
# Epoch 38/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0458 - accuracy: 0.9854 - val_loss: 0.5377 - val_accuracy: 0.8841
# Epoch 39/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0675 - accuracy: 0.9833 - val_loss: 0.8558 - val_accuracy: 0.8734
# Epoch 40/40
# 105/105 [==============================] - 7s 61ms/step - loss: 0.0778 - accuracy: 0.9758 - val_loss: 0.6310 - val_accuracy: 0.8937

# %%
# 2)
# Evaluate the model on the validation data
val_loss, val_accuracy = model.evaluate(val_data)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)
# Out:
# 27/27 [==============================] - 1s 26ms/step - loss: 0.6310 - accuracy: 0.8937
# Validation Loss: 0.6309828758239746
# Validation Accuracy: 0.8936678767204285

# %%
# 2)
# plotting the loss and accuracy
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy normalization')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss normalization')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train'], loc='upper left')
plt.show()
